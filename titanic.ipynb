# %%
import random

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score

# %%
train = pd.read_csv('train.csv', sep=',')
train_df = train.drop(columns=["PassengerId"], axis=1)

# %%
display(train_df)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test = pd.read_csv('test.csv', sep=',')
test_df = test.drop(columns=["PassengerId"], axis=1)

# %%
display(test_df)
# Out:
#      Pclass                                          Name     Sex   Age  \
# 0         3                              Kelly, Mr. James    male  34.5
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                     Myles, Mr. Thomas Francis    male  62.0
# 3         3                              Wirz, Mr. Albert    male  27.0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..      ...                                           ...     ...   ...
# 413       3                            Spector, Mr. Woolf    male   NaN
# 414       1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415       3                  Saether, Mr. Simon Sivertsen    male  38.5
# 416       3                           Ware, Mr. Frederick    male   NaN
# 417       3                      Peter, Master. Michael J    male   NaN
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked
# 0        0      0              330911    7.8292   NaN        Q
# 1        1      0              363272    7.0000   NaN        S
# 2        0      0              240276    9.6875   NaN        Q
# 3        0      0              315154    8.6625   NaN        S
# 4        1      1             3101298   12.2875   NaN        S
# ..     ...    ...                 ...       ...   ...      ...
# 413      0      0           A.5. 3236    8.0500   NaN        S
# 414      0      0            PC 17758  108.9000  C105        C
# 415      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0      0              359309    8.0500   NaN        S
# 417      1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
cell_hover = {  # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': 'background-color: #000066; color: white'
#     'props': [('background-color', '#ffffb3'; 'color')]
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: darkgrey; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #000066; color: white;'
}

table_styles = [cell_hover, index_names, headers]
set_properties = {"background-color": "#023e8a","color":"white","border": "1.3px solid white"}

styles = train_df.sample(10).style.set_table_styles(table_styles).set_properties(**set_properties).highlight_null(null_color="#c600de").set_caption("10 sample records from the dataset.")
styles
# Out:
# <style type="text/css">
# #T_57141 td:hover {
#   background-color: #000066;
#   color: white;
# }
# #T_57141 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_57141 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_57141_row0_col0, #T_57141_row0_col1, #T_57141_row0_col2, #T_57141_row0_col3, #T_57141_row0_col4, #T_57141_row0_col5, #T_57141_row0_col6, #T_57141_row0_col7, #T_57141_row0_col8, #T_57141_row0_col10, #T_57141_row1_col0, #T_57141_row1_col1, #T_57141_row1_col2, #T_57141_row1_col3, #T_57141_row1_col5, #T_57141_row1_col6, #T_57141_row1_col7, #T_57141_row1_col8, #T_57141_row1_col10, #T_57141_row2_col0, #T_57141_row2_col1, #T_57141_row2_col2, #T_57141_row2_col3, #T_57141_row2_col5, #T_57141_row2_col6, #T_57141_row2_col7, #T_57141_row2_col8, #T_57141_row2_col10, #T_57141_row3_col0, #T_57141_row3_col1, #T_57141_row3_col2, #T_57141_row3_col3, #T_57141_row3_col4, #T_57141_row3_col5, #T_57141_row3_col6, #T_57141_row3_col7, #T_57141_row3_col8, #T_57141_row3_col10, #T_57141_row4_col0, #T_57141_row4_col1, #T_57141_row4_col2, #T_57141_row4_col3, #T_57141_row4_col5, #T_57141_row4_col6, #T_57141_row4_col7, #T_57141_row4_col8, #T_57141_row4_col10, #T_57141_row5_col0, #T_57141_row5_col1, #T_57141_row5_col2, #T_57141_row5_col3, #T_57141_row5_col5, #T_57141_row5_col6, #T_57141_row5_col7, #T_57141_row5_col8, #T_57141_row5_col10, #T_57141_row6_col0, #T_57141_row6_col1, #T_57141_row6_col2, #T_57141_row6_col3, #T_57141_row6_col4, #T_57141_row6_col5, #T_57141_row6_col6, #T_57141_row6_col7, #T_57141_row6_col8, #T_57141_row6_col9, #T_57141_row6_col10, #T_57141_row7_col0, #T_57141_row7_col1, #T_57141_row7_col2, #T_57141_row7_col3, #T_57141_row7_col4, #T_57141_row7_col5, #T_57141_row7_col6, #T_57141_row7_col7, #T_57141_row7_col8, #T_57141_row7_col10, #T_57141_row8_col0, #T_57141_row8_col1, #T_57141_row8_col2, #T_57141_row8_col3, #T_57141_row8_col4, #T_57141_row8_col5, #T_57141_row8_col6, #T_57141_row8_col7, #T_57141_row8_col8, #T_57141_row8_col10, #T_57141_row9_col0, #T_57141_row9_col1, #T_57141_row9_col2, #T_57141_row9_col3, #T_57141_row9_col4, #T_57141_row9_col5, #T_57141_row9_col6, #T_57141_row9_col7, #T_57141_row9_col8, #T_57141_row9_col10 {
#   background-color: #023e8a;
#   color: white;
#   border: 1.3px solid white;
# }
# #T_57141_row0_col9, #T_57141_row1_col4, #T_57141_row1_col9, #T_57141_row2_col4, #T_57141_row2_col9, #T_57141_row3_col9, #T_57141_row4_col4, #T_57141_row4_col9, #T_57141_row5_col4, #T_57141_row5_col9, #T_57141_row7_col9, #T_57141_row8_col9, #T_57141_row9_col9 {
#   background-color: #023e8a;
#   color: white;
#   border: 1.3px solid white;
#   background-color: #c600de;
# }
# </style>
# <table id="T_57141">
#   <caption>10 sample records from the dataset.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57141_level0_col0" class="col_heading level0 col0" >Survived</th>
#       <th id="T_57141_level0_col1" class="col_heading level0 col1" >Pclass</th>
#       <th id="T_57141_level0_col2" class="col_heading level0 col2" >Name</th>
#       <th id="T_57141_level0_col3" class="col_heading level0 col3" >Sex</th>
#       <th id="T_57141_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_57141_level0_col5" class="col_heading level0 col5" >SibSp</th>
#       <th id="T_57141_level0_col6" class="col_heading level0 col6" >Parch</th>
#       <th id="T_57141_level0_col7" class="col_heading level0 col7" >Ticket</th>
#       <th id="T_57141_level0_col8" class="col_heading level0 col8" >Fare</th>
#       <th id="T_57141_level0_col9" class="col_heading level0 col9" >Cabin</th>
#       <th id="T_57141_level0_col10" class="col_heading level0 col10" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57141_level0_row0" class="row_heading level0 row0" >163</th>
#       <td id="T_57141_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_57141_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_57141_row0_col2" class="data row0 col2" >Calic, Mr. Jovo</td>
#       <td id="T_57141_row0_col3" class="data row0 col3" >male</td>
#       <td id="T_57141_row0_col4" class="data row0 col4" >17.000000</td>
#       <td id="T_57141_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_57141_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_57141_row0_col7" class="data row0 col7" >315093</td>
#       <td id="T_57141_row0_col8" class="data row0 col8" >8.662500</td>
#       <td id="T_57141_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_57141_row0_col10" class="data row0 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_57141_level0_row1" class="row_heading level0 row1" >507</th>
#       <td id="T_57141_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_57141_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_57141_row1_col2" class="data row1 col2" >Bradley, Mr. George ("George Arthur Brayton")</td>
#       <td id="T_57141_row1_col3" class="data row1 col3" >male</td>
#       <td id="T_57141_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_57141_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_57141_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_57141_row1_col7" class="data row1 col7" >111427</td>
#       <td id="T_57141_row1_col8" class="data row1 col8" >26.550000</td>
#       <td id="T_57141_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_57141_row1_col10" class="data row1 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_57141_level0_row2" class="row_heading level0 row2" >19</th>
#       <td id="T_57141_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_57141_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_57141_row2_col2" class="data row2 col2" >Masselmani, Mrs. Fatima</td>
#       <td id="T_57141_row2_col3" class="data row2 col3" >female</td>
#       <td id="T_57141_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_57141_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_57141_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_57141_row2_col7" class="data row2 col7" >2649</td>
#       <td id="T_57141_row2_col8" class="data row2 col8" >7.225000</td>
#       <td id="T_57141_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_57141_row2_col10" class="data row2 col10" >C</td>
#     </tr>
#     <tr>
#       <th id="T_57141_level0_row3" class="row_heading level0 row3" >519</th>
#       <td id="T_57141_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_57141_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_57141_row3_col2" class="data row3 col2" >Pavlovic, Mr. Stefo</td>
#       <td id="T_57141_row3_col3" class="data row3 col3" >male</td>
#       <td id="T_57141_row3_col4" class="data row3 col4" >32.000000</td>
#       <td id="T_57141_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_57141_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_57141_row3_col7" class="data row3 col7" >349242</td>
#       <td id="T_57141_row3_col8" class="data row3 col8" >7.895800</td>
#       <td id="T_57141_row3_col9" class="data row3 col9" >nan</td>
#       <td id="T_57141_row3_col10" class="data row3 col10" >S</td>
#     </tr>
#     <tr>
#       <th id="T_57141_level0_row4" class="row_heading level0 row4" >459</th>
#       <td id="T_57141_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_57141_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_57141_row4_col2" class="data row4 col2" >O'Connor, Mr. Maurice</td>
#       <td id="T_57141_row4_col3" class="data row4 col3" >male</td>
#       <td id="T_57141_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_57141_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_57141_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_57141_row4_col7" class="data row4 col7" >371060</td>
#       <td id="T_57141_row4_col8" class="data row4 col8" >7.750000</td>
#       <td id="T_57141_row4_col9" class="data row4 col9" >nan</td>
#       <td id="T_57141_row4_col10" class="data row4 col10" >Q</td>
#     </tr>
#     <tr>
#       <th id="T_57141_level0_row5" class="row_headi

# %%
print("\033[1mSome basic information about the dataset.\033[0m\n")

train_df.info()
# Out:
# Some basic information about the dataset.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
def missing_conditional_coloring(val):
    """
    If the value is between 0 to 10, then highlight with a different color and
    if the value if larger than 10 then highligh that value with a different
    color or left as it is.
    """
    val = val.tolist()
    return ['background-color:#e14258;color:white' if i > 10 else 'background-color:#c600de;color:white' if (i > 0 and i < 10) else 'background-color:#023e8a;color:white' for i in val]


total_missing_df = pd.DataFrame(train_df.isnull().sum() / train_df.shape[0] * 100, columns=["% (df)"])
total_missing_test_df = pd.DataFrame(test_df.isnull().sum() / test_df.shape[0] * 100, columns=["% (test df)"])
missing = pd.concat([total_missing_df, total_missing_test_df], axis=1)
missing.T.style.set_table_styles(table_styles).set_properties(**set_properties).highlight_null(null_color="#c600de").apply(missing_conditional_coloring).set_caption("Missing values to every column in terms of %")
# Out:
# <style type="text/css">
# #T_7925a td:hover {
#   background-color: #000066;
#   color: white;
# }
# #T_7925a .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_7925a th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_7925a_row0_col0, #T_7925a_row0_col1, #T_7925a_row0_col2, #T_7925a_row0_col3, #T_7925a_row0_col5, #T_7925a_row0_col6, #T_7925a_row0_col7, #T_7925a_row0_col8, #T_7925a_row1_col1, #T_7925a_row1_col2, #T_7925a_row1_col3, #T_7925a_row1_col5, #T_7925a_row1_col6, #T_7925a_row1_col7, #T_7925a_row1_col10 {
#   background-color: #023e8a;
#   color: white;
#   border: 1.3px solid white;
#   background-color: #023e8a;
#   color: white;
# }
# #T_7925a_row0_col4, #T_7925a_row0_col9, #T_7925a_row1_col4, #T_7925a_row1_col9 {
#   background-color: #023e8a;
#   color: white;
#   border: 1.3px solid white;
#   background-color: #e14258;
#   color: white;
# }
# #T_7925a_row0_col10, #T_7925a_row1_col8 {
#   background-color: #023e8a;
#   color: white;
#   border: 1.3px solid white;
#   background-color: #c600de;
#   color: white;
# }
# #T_7925a_row1_col0 {
#   background-color: #023e8a;
#   color: white;
#   border: 1.3px solid white;
#   background-color: #c600de;
#   background-color: #023e8a;
#   color: white;
# }
# </style>
# <table id="T_7925a">
#   <caption>Missing values to every column in terms of %</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7925a_level0_col0" class="col_heading level0 col0" >Survived</th>
#       <th id="T_7925a_level0_col1" class="col_heading level0 col1" >Pclass</th>
#       <th id="T_7925a_level0_col2" class="col_heading level0 col2" >Name</th>
#       <th id="T_7925a_level0_col3" class="col_heading level0 col3" >Sex</th>
#       <th id="T_7925a_level0_col4" class="col_heading level0 col4" >Age</th>
#       <th id="T_7925a_level0_col5" class="col_heading level0 col5" >SibSp</th>
#       <th id="T_7925a_level0_col6" class="col_heading level0 col6" >Parch</th>
#       <th id="T_7925a_level0_col7" class="col_heading level0 col7" >Ticket</th>
#       <th id="T_7925a_level0_col8" class="col_heading level0 col8" >Fare</th>
#       <th id="T_7925a_level0_col9" class="col_heading level0 col9" >Cabin</th>
#       <th id="T_7925a_level0_col10" class="col_heading level0 col10" >Embarked</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7925a_level0_row0" class="row_heading level0 row0" >% (df)</th>
#       <td id="T_7925a_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_7925a_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_7925a_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_7925a_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_7925a_row0_col4" class="data row0 col4" >19.865320</td>
#       <td id="T_7925a_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_7925a_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_7925a_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_7925a_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_7925a_row0_col9" class="data row0 col9" >77.104377</td>
#       <td id="T_7925a_row0_col10" class="data row0 col10" >0.224467</td>
#     </tr>
#     <tr>
#       <th id="T_7925a_level0_row1" class="row_heading level0 row1" >% (test df)</th>
#       <td id="T_7925a_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_7925a_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_7925a_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_7925a_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_7925a_row1_col4" class="data row1 col4" >20.574163</td>
#       <td id="T_7925a_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_7925a_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_7925a_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_7925a_row1_col8" class="data row1 col8" >0.239234</td>
#       <td id="T_7925a_row1_col9" class="data row1 col9" >78.229665</td>
#       <td id="T_7925a_row1_col10" class="data row1 col10" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_df.describe().style.set_table_styles(table_styles).set_properties(**set_properties).highlight_null(null_color="#c600de").set_caption("Some basic statistical values of the dataset.")
# Out:
# <style type="text/css">
# #T_fe7a8 td:hover {
#   background-color: #000066;
#   color: white;
# }
# #T_fe7a8 .index_name {
#   font-style: italic;
#   color: darkgrey;
#   font-weight: normal;
# }
# #T_fe7a8 th:not(.index_name) {
#   background-color: #000066;
#   color: white;
# }
# #T_fe7a8_row0_col0, #T_fe7a8_row0_col1, #T_fe7a8_row0_col2, #T_fe7a8_row0_col3, #T_fe7a8_row0_col4, #T_fe7a8_row0_col5, #T_fe7a8_row1_col0, #T_fe7a8_row1_col1, #T_fe7a8_row1_col2, #T_fe7a8_row1_col3, #T_fe7a8_row1_col4, #T_fe7a8_row1_col5, #T_fe7a8_row2_col0, #T_fe7a8_row2_col1, #T_fe7a8_row2_col2, #T_fe7a8_row2_col3, #T_fe7a8_row2_col4, #T_fe7a8_row2_col5, #T_fe7a8_row3_col0, #T_fe7a8_row3_col1, #T_fe7a8_row3_col2, #T_fe7a8_row3_col3, #T_fe7a8_row3_col4, #T_fe7a8_row3_col5, #T_fe7a8_row4_col0, #T_fe7a8_row4_col1, #T_fe7a8_row4_col2, #T_fe7a8_row4_col3, #T_fe7a8_row4_col4, #T_fe7a8_row4_col5, #T_fe7a8_row5_col0, #T_fe7a8_row5_col1, #T_fe7a8_row5_col2, #T_fe7a8_row5_col3, #T_fe7a8_row5_col4, #T_fe7a8_row5_col5, #T_fe7a8_row6_col0, #T_fe7a8_row6_col1, #T_fe7a8_row6_col2, #T_fe7a8_row6_col3, #T_fe7a8_row6_col4, #T_fe7a8_row6_col5, #T_fe7a8_row7_col0, #T_fe7a8_row7_col1, #T_fe7a8_row7_col2, #T_fe7a8_row7_col3, #T_fe7a8_row7_col4, #T_fe7a8_row7_col5 {
#   background-color: #023e8a;
#   color: white;
#   border: 1.3px solid white;
# }
# </style>
# <table id="T_fe7a8">
#   <caption>Some basic statistical values of the dataset.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe7a8_level0_col0" class="col_heading level0 col0" >Survived</th>
#       <th id="T_fe7a8_level0_col1" class="col_heading level0 col1" >Pclass</th>
#       <th id="T_fe7a8_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_fe7a8_level0_col3" class="col_heading level0 col3" >SibSp</th>
#       <th id="T_fe7a8_level0_col4" class="col_heading level0 col4" >Parch</th>
#       <th id="T_fe7a8_level0_col5" class="col_heading level0 col5" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe7a8_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_fe7a8_row0_col0" class="data row0 col0" >891.000000</td>
#       <td id="T_fe7a8_row0_col1" class="data row0 col1" >891.000000</td>
#       <td id="T_fe7a8_row0_col2" class="data row0 col2" >714.000000</td>
#       <td id="T_fe7a8_row0_col3" class="data row0 col3" >891.000000</td>
#       <td id="T_fe7a8_row0_col4" class="data row0 col4" >891.000000</td>
#       <td id="T_fe7a8_row0_col5" class="data row0 col5" >891.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a8_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_fe7a8_row1_col0" class="data row1 col0" >0.383838</td>
#       <td id="T_fe7a8_row1_col1" class="data row1 col1" >2.308642</td>
#       <td id="T_fe7a8_row1_col2" class="data row1 col2" >29.699118</td>
#       <td id="T_fe7a8_row1_col3" class="data row1 col3" >0.523008</td>
#       <td id="T_fe7a8_row1_col4" class="data row1 col4" >0.381594</td>
#       <td id="T_fe7a8_row1_col5" class="data row1 col5" >32.204208</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a8_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_fe7a8_row2_col0" class="data row2 col0" >0.486592</td>
#       <td id="T_fe7a8_row2_col1" class="data row2 col1" >0.836071</td>
#       <td id="T_fe7a8_row2_col2" class="data row2 col2" >14.526497</td>
#       <td id="T_fe7a8_row2_col3" class="data row2 col3" >1.102743</td>
#       <td id="T_fe7a8_row2_col4" class="data row2 col4" >0.806057</td>
#       <td id="T_fe7a8_row2_col5" class="data row2 col5" >49.693429</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a8_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_fe7a8_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_fe7a8_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_fe7a8_row3_col2" class="data row3 col2" >0.420000</td>
#       <td id="T_fe7a8_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_fe7a8_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_fe7a8_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a8_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_fe7a8_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_fe7a8_row4_col1" class="data row4 col1" >2.000000</td>
#       <td id="T_fe7a8_row4_col2" class="data row4 col2" >20.125000</td>
#       <td id="T_fe7a8_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_fe7a8_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_fe7a8_row4_col5" class="data row4 col5" >7.910400</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a8_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_fe7a8_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_fe7a8_row5_col1" class="data row5 col1" >3.000000</td>
#       <td id="T_fe7a8_row5_col2" class="data row5 col2" >28.000000</td>
#       <td id="T_fe7a8_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_fe7a8_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_fe7a8_row5_col5" class="data row5 col5" >14.454200</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a8_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_fe7a8_row6_col0" class="data row6 col0" >1.000000</td>
#       <td id="T_fe7a8_row6_col1" class="data row6 col1" >3.000000</td>
#       <td id="T_fe7a8_row6_col2" class="data row6 col2" >38.000000</td>
#       <td id="T_fe7a8_row6_col3" class="data row6 col3" >1.000000</td>
#       <td id="T_fe7a8_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_fe7a8_row6_col5" class="data row6 col5" >31.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fe7a8_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_fe7a8_row7_col0" class="data row7 col0" >1.000000</td>
#       <td id="T_fe7a8_row7_col1" class="data row7 col1" >3.000000</td>
#       <td id="T_fe7a8_row7_col2" class="data row7 col2" >80.000000</td>
#       <td id="T_fe7a8_row7_col3" class="data row7 col3" >8.000000</td>
#       <td id="T_fe7a8_row7_col4" class="data row7 col4" >6.000000</td>
#       <td id="T_fe7a8_row7_col5" class="data row7 col5" >512.329200</td>
#     </tr>
#   </tbody>
# </table>
